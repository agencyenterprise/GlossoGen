# %% [markdown]
# # Scoring a run
#
# Metrics are generic. A scenario opts into each one by implementing the hook that
# metric reads, so a measurement written once works on every scenario, including one
# installed from another package.
#
# This notebook scores a run through `run_scenario_evaluation`, the same function
# `glossogen evaluate` calls. Nothing is reimplemented for the notebook, so what you
# see here is what the CLI would write.

# %%
import os
import tempfile
from pathlib import Path

from pytest import MonkeyPatch

# These notebooks generate their own run, so nothing here reaches a provider.
# Clearing the keys makes that a fact rather than a claim: if any cell below
# tried to call a model, it would fail here rather than spend.
for _key in ("ANTHROPIC_API_KEY", "OPENAI_API_KEY", "HF_TOKEN"):
    os.environ.pop(_key, None)

SCENARIO = "warehouse_robot_recovery"
PRESET = "knobs_default"

# %%
from glossogen.testing import run_rounds


async def generate_run(round_count, overrides):
    """Run the real round loop with the model replaced by a script.

    Every part of the platform is real here: the MCP server, the tool dispatch,
    the game clock, the world and the event logger. Only the LLM is scripted, so
    this costs nothing, needs no key, and gives the same answer every time.
    """
    with MonkeyPatch.context() as patch:
        return await run_rounds(
            scenario_name=SCENARIO,
            preset_name=PRESET,
            round_count=round_count,
            overrides=overrides,
            tmp_path=Path(tempfile.mkdtemp()),
            monkeypatch=patch,
        )


result = await generate_run(round_count=4, overrides={})
print(f"{len(result.events)} events at {result.log_path}")
# Out:
# [08/17/26 15:07:13] INFO     Registered scenario MCP tool: perform_recovery                        ]8;id=6020853;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py\mcp_tools.py]8;;\:]8;id=6020854;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py#600\600]8;;\
#                     INFO     MCP server mounted for in-process dispatch                ]8;id=6020861;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/autonomous_supervisor.py\autonomous_supervisor.py]8;;\:]8;id=6020862;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/autonomous_supervisor.py#115\115]8;;\
#                     INFO     Game clock started. Round 1/4, injections delivered.                 ]8;id=6020869;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/game_clock.py\game_clock.py]8;;\:]8;id=6020870;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/game_clock.py#210\210]8;;\
#                     INFO     Starting Pydantic AI agent floor_associate (Floor Associate) ]8;id=6020877;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6020878;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#260\260]8;;\
#                              max_turns=30 provider=anthropic
#                              model=scripted::floor_associate
# [08/17/26 15:07:14] INFO     Launched agent floor_associate (Floor Associate)          ]8;id=6020884;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/autonomous_supervisor.py\autonomous_supervisor.py]8;;\:]8;id=6020885;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/autonomous_supervisor.py#497\497]8;;\
#                     INFO     Starting Pydantic AI agent robotics_engineer (Robotics       ]8;id=6020890;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6020891;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#260\260]8;;\
#                              Engineer) max_turns=30 provider=anthropic
#                              model=scripted::robotics_engineer
#                     INFO     Launched agent robotics_engineer (Robotics Engineer)      ]8;id=6020896;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/autonomous_supervisor.py\autonomous_supervisor.py]8;;\:]8;id=6020897;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/autonomous_supervisor.py#497\497]8;;\
#                     INFO     Starting Pydantic AI agent fleet_safety_coordinator (Fleet   ]8;id=6020902;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6020903;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#260\260]8;;\
#                              Safety Coordinator) max_turns=30 provider=anthropic
#                              model=scripted::fleet_safety_coordinator
#                     INFO     Launched agent fleet_safety_coordinator (Fleet Safety     ]8;id=6020908;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/autonomous_supervisor.py\autonomous_supervisor.py]8;;\:]8;id=6020909;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/autonomous_supervisor.py#497\497]8;;\
#                              Coordinator)
#                     INFO     Processing request of type ListToolsRequest                              ]8;id=6020916;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6020917;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Processing request of type ListToolsRequest                              ]8;id=6020922;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6020923;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Processing request of type ListToolsRequest                              ]8;id=6020928;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6020929;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Agent floor_associate tool call: send_message({"channel_id": ]8;id=6020935;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6020936;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                              "radio", "text": "floor_associate reporting", "force":
#                              true})
#                     INFO     Agent robotics_engineer tool call:                           ]8;id=6020941;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6020942;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                              send_message({"channel_id": "radio", "text":
#                              "robotics_engineer reporting", "force": true})
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6020947;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6020948;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Agent fleet_safety_coordinator tool call:                    ]8;id=6020953;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6020954;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                              send_message({"channel_id": "radio", "text":
#                              "fleet_safety_coordinator reporting", "force": true})
#                     INFO     Agent floor_associate sent 2 tokens to channel radio                  ]8;id=6020960;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py\mcp_tools.py]8;;\:]8;id=6020961;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py#528\528]8;;\
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6020966;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6020967;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6020972;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6020973;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Agent robotics_engineer sent 2 tokens to channel radio                ]8;id=6020978;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py\mcp_tools.py]8;;\:]8;id=6020979;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py#528\528]8;;\
#                     INFO     Agent floor_associate reasoning:                             ]8;id=6020985;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6020986;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent fleet_safety_coordinator sent 2 tokens to channel radio         ]8;id=6020991;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py\mcp_tools.py]8;;\:]8;id=6020992;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py#528\528]8;;\
#                     INFO     Agent robotics_engineer reasoning:                           ]8;id=6020997;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6020998;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent floor_associate cycle 1 complete: in=100 out=9         ]8;id=6021004;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021005;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              cache_read=0 cache_write=0 tokens
#                     INFO     Agent floor_associate reasoning: done                        ]8;id=6021010;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021011;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent fleet_safety_coordinator reasoning:                    ]8;id=6021016;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021017;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent robotics_engineer cycle 1 complete: in=100 out=9       ]8;id=6021022;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021023;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              cache_read=0 cache_write=0 tokens
#                     INFO     Agent robotics_engineer reasoning: done                      ]8;id=6021028;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021029;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent fleet_safety_coordinator cycle 1 complete: in=100      ]8;id=6021034;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021035;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              out=9 cache_read=0 cache_write=0 tokens
#                     INFO     Agent fleet_safety_coordinator reasoning: done               ]8;id=6021040;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021041;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent floor_associate tool call: send_message({"channel_id": ]8;id=6021046;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021047;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                              "radio", "text": "floor_associate reporting", "force":
#                              true})
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6021052;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6021053;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Agent robotics_engineer tool call:                           ]8;id=6021058;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021059;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                              send_message({"channel_id": "radio", "text":
#                              "robotics_engineer reporting", "force": true})
#                     INFO     Agent floor_associate sent 2 tokens to channel radio                  ]8;id=6021064;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py\mcp_tools.py]8;;\:]8;id=6021065;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py#528\528]8;;\
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6021070;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6021071;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Agent robotics_engineer sent 2 tokens to channel radio                ]8;id=6021076;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py\mcp_tools.py]8;;\:]8;id=6021077;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py#528\528]8;;\
#                     INFO     Agent fleet_safety_coordinator tool call:                    ]8;id=6021082;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021083;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                              send_message({"channel_id": "radio", "text":
#                              "fleet_safety_coordinator reporting", "force": true})
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6021088;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6021089;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Agent floor_associate reasoning:                             ]8;id=6021094;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021095;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent robotics_engineer reasoning:                           ]8;id=6021100;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021101;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent floor_associate cycle 2 complete: in=100 out=9         ]8;id=6021106;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021107;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              cache_read=0 cache_write=0 tokens
#                     INFO     Agent floor_associate reasoning: done                        ]8;id=6021112;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021113;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent robotics_engineer cycle 2 complete: in=100 out=9       ]8;id=6021118;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021119;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              cache_read=0 cache_write=0 tokens
#                     INFO     Agent robotics_engineer reasoning: done                      ]8;id=6021124;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021125;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent fleet_safety_coordinator sent 2 tokens to channel radio         ]8;id=6021130;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py\mcp_tools.py]8;;\:]8;id=6021131;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py#528\528]8;;\
#                     INFO     Agent floor_associate tool call: send_message({"channel_id": ]8;id=6021136;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021137;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                              "radio", "text": "floor_associate reporting", "force":
#                              true})
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6021142;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6021143;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Agent robotics_engineer tool call:                           ]8;id=6021148;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021149;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                              send_message({"channel_id": "radio", "text":
#                              "robotics_engineer reporting", "force": true})
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6021154;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6021155;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Agent floor_associate sent 2 tokens to channel radio                  ]8;id=6021160;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py\mcp_tools.py]8;;\:]8;id=6021161;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py#528\528]8;;\
#                     INFO     Agent fleet_safety_coordinator reasoning:                    ]8;id=6021166;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021167;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent fleet_safety_coordinator cycle 2 complete: in=100      ]8;id=6021172;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021173;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              out=9 cache_read=0 cache_write=0 tokens
#                     INFO     Agent fleet_safety_coordinator reasoning: done               ]8;id=6021178;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021179;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Round 1 ending early via scenario trigger:                           ]8;id=6021185;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/game_clock.py\game_clock.py]8;;\:]8;id=6021186;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/game_clock.py#274\274]8;;\
#                              communication_budget_exceeded
#                     INFO     Agent floor_associate reasoning:                             ]8;id=6021191;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021192;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent floor_associate cycle 3 complete: in=100 out=9         ]8;id=6021197;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021198;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              cache_read=0 cache_write=0 tokens
#                     INFO     Agent floor_associate reasoning: done                        ]8;id=6021203;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021204;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent fleet_safety_coordinator tool call:                    ]8;id=6021209;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021210;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                              send_message({"channel_id": "radio", "text":
#                              "fleet_safety_coordinator reporting", "force": true})
#                     INFO     Agent robotics_engineer sent 2 tokens to channel radio                ]8;id=6021215;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py\mcp_tools.py]8;;\:]8;id=6021216;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py#528\528]8;;\
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6021221;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6021222;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Postmortem started for round 1                                 ]8;id=6021229;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/simulation_state.py\simulation_state.py]8;;\:]8;id=6021230;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/simulation_state.py#324\324]8;;\
#                     INFO     Agent fleet_safety_coordinator sent 2 tokens to channel radio         ]8;id=6021235;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py\mcp_tools.py]8;;\:]8;id=6021236;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py#528\528]8;;\
#                     INFO     Agent floor_associate tool call: send_message({"channel_id": ]8;id=6021241;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021242;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                              "radio", "text": "floor_associate reporting", "force":
#                              true})
#                     INFO     Agent robotics_engineer reasoning:                           ]8;id=6021247;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021248;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6021253;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6021254;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Agent fleet_safety_coordinator reasoning:                    ]8;id=6021259;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021260;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent robotics_engineer cycle 3 complete: in=100 out=9       ]8;id=6021265;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021266;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              cache_read=0 cache_write=0 tokens
#                     INFO     Agent robotics_engineer reasoning: done                      ]8;id=6021271;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021272;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent floor_associate reasoning:                             ]8;id=6021277;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021278;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent fleet_safety_coordinator cycle 3 complete: in=100      ]8;id=6021283;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021284;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              out=9 cache_read=0 cache_write=0 tokens
#                     INFO     Agent fleet_safety_coordinator reasoning: done               ]8;id=6021289;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021290;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent floor_associate cycle 4 complete: in=100 out=9         ]8;id=6021295;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021296;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              cache_read=0 cache_write=0 tokens
#                     INFO     Agent floor_associate reasoning: done                        ]8;id=6021301;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021302;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent robotics_engineer tool call:                           ]8;id=6021307;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021308;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                              send_message({"channel_id": "radio", "text":
#                              "robotics_engineer reporting", "force": true})
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6021313;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6021314;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Agent fleet_safety_coordinator tool call:                    ]8;id=6021319;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021320;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                              send_message({"channel_id": "radio", "text":
#                              "fleet_safety_coordinator reporting", "force": true})
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6021325;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6021326;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Agent floor_associate tool call: read_notifications({})      ]8;id=6021331;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021332;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                     INFO     Agent robotics_engineer reasoning:                           ]8;id=6021337;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021338;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6021343;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6021344;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Agent fleet_safety_coordinator reasoning:                    ]8;id=6021349;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021350;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent robotics_engineer cycle 4 complete: in=100 out=9       ]8;id=6021355;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021356;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              cache_read=0 cache_write=0 tokens
#                     INFO     Agent robotics_engineer reasoning: done                      ]8;id=6021361;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021362;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent fleet_safety_coordinator cycle 4 complete: in=100      ]8;id=6021367;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021368;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              out=9 cache_read=0 cache_write=0 tokens
#                     INFO     Agent fleet_safety_coordinator reasoning: done               ]8;id=6021373;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021374;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent robotics_engineer tool call: read_notifications({})    ]8;id=6021379;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021380;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6021385;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6021386;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Agent fleet_safety_coordinator tool call:                    ]8;id=6021391;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021392;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                              read_notifications({})
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6021397;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6021398;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Agent floor_associate read_notifications rejected: parallel call      ]8;id=6021404;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py\mcp_tools.py]8;;\:]8;id=6021405;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py#266\266]8;;\
#                              detected (active_non_blocking_calls=0, rn_in_flight=False,
#                              sibling_dispatched_recently=True)
#                     INFO     Agent floor_associate reasoning:                             ]8;id=6021410;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021411;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent floor_associate cycle 5 complete: in=100 out=2         ]8;id=6021416;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021417;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              cache_read=0 cache_write=0 tokens
#                     INFO     Agent floor_associate reasoning: idle                        ]8;id=6021422;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021423;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent floor_associate tool call: read_notifications({})      ]8;id=6021428;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021429;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6021434;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6021435;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Agent robotics_engineer read_notifications rejected: parallel call    ]8;id=6021440;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py\mcp_tools.py]8;;\:]8;id=6021441;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py#266\266]8;;\
#                              detected (active_non_blocking_calls=0, rn_in_flight=False,
#                              sibling_dispatched_recently=True)
#                     INFO     Agent fleet_safety_coordinator read_notifications rejected: parallel  ]8;id=6021446;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py\mcp_tools.py]8;;\:]8;id=6021447;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py#266\266]8;;\
#                              call detected (active_non_blocking_calls=0, rn_in_flight=False,
#                              sibling_dispatched_recently=True)
#                     INFO     Agent robotics_engineer reasoning:                           ]8;id=6021452;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021453;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent fleet_safety_coordinator reasoning:                    ]8;id=6021458;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021459;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent robotics_engineer cycle 5 complete: in=100 out=2       ]8;id=6021464;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021465;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              cache_read=0 cache_write=0 tokens
#                     INFO     Agent robotics_engineer reasoning: idle                      ]8;id=6021470;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021471;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent fleet_safety_coordinator cycle 5 complete: in=100      ]8;id=6021476;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021477;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              out=2 cache_read=0 cache_write=0 tokens
#                     INFO     Agent fleet_safety_coordinator reasoning: idle               ]8;id=6021482;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021483;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent robotics_engineer tool call: read_notifications({})    ]8;id=6021488;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021489;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                     INFO     Agent fleet_safety_coordinator tool call:                    ]8;id=6021494;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021495;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                              read_notifications({})
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6021500;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6021501;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6021506;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6021507;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Agent floor_associate read_notifications rejected: parallel call      ]8;id=6021512;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py\mcp_tools.py]8;;\:]8;id=6021513;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py#266\266]8;;\
#                              detected (active_non_blocking_calls=0, rn_in_flight=False,
#                              sibling_dispatched_recently=True)
#                     INFO     Agent floor_associate reasoning:                             ]8;id=6021518;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021519;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent floor_associate cycle 6 complete: in=100 out=2         ]8;id=6021524;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021525;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              cache_read=0 cache_write=0 tokens
#                     INFO     Agent floor_associate reasoning: idle                        ]8;id=6021530;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021531;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent floor_associate tool call: read_notifications({})      ]8;id=6021536;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021537;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6021542;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6021543;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Agent robotics_engineer read_notifications rejected: parallel call    ]8;id=6021548;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py\mcp_tools.py]8;;\:]8;id=6021549;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py#266\266]8;;\
#                              detected (active_non_blocking_calls=0, rn_in_flight=False,
#                              sibling_dispatched_recently=True)
#                     INFO     Agent fleet_safety_coordinator read_notifications rejected: parallel  ]8;id=6021554;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py\mcp_tools.py]8;;\:]8;id=6021555;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py#266\266]8;;\
#                              call detected (active_non_blocking_calls=0, rn_in_flight=False,
#                              sibling_dispatched_recently=True)
#                     INFO     Agent robotics_engineer reasoning:                           ]8;id=6021560;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021561;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent fleet_safety_coordinator reasoning:                    ]8;id=6021566;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021567;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent robotics_engineer cycle 6 complete: in=100 out=2       ]8;id=6021572;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021573;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              cache_read=0 cache_write=0 tokens
#                     INFO     Agent robotics_engineer reasoning: idle                      ]8;id=6021578;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021579;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent fleet_safety_coordinator cycle 6 complete: in=100      ]8;id=6021584;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021585;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              out=2 cache_read=0 cache_write=0 tokens
#                     INFO     Agent fleet_safety_coordinator reasoning: idle               ]8;id=6021590;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021591;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent robotics_engineer tool call: read_notifications({})    ]8;id=6021596;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021597;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                     INFO     Agent fleet_safety_coordinator tool call:                    ]8;id=6021602;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6021603;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                              read_notifications({})
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6021608;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6021609;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6021614;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6021615;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Agent floor_associate read_notifications rejected: parallel call      ]8;id=6021620;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py\mcp_tools.py]8;;\:]8;id=6021621;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/mcp_tools.py#266\266]8;;\
# ...
#                              read_notifications({})
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6023115;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6023116;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Agent floor_associate reasoning:                             ]8;id=6023121;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023122;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent robotics_engineer reasoning:                           ]8;id=6023127;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023128;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent floor_associate cycle 23 complete: in=100 out=2        ]8;id=6023133;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023134;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              cache_read=0 cache_write=0 tokens
#                     INFO     Agent floor_associate reasoning: idle                        ]8;id=6023139;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023140;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent fleet_safety_coordinator reasoning:                    ]8;id=6023145;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023146;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent robotics_engineer cycle 23 complete: in=100 out=2      ]8;id=6023151;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023152;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              cache_read=0 cache_write=0 tokens
#                     INFO     Agent robotics_engineer reasoning: idle                      ]8;id=6023157;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023158;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent fleet_safety_coordinator cycle 22 complete: in=100     ]8;id=6023163;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023164;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              out=2 cache_read=0 cache_write=0 tokens
#                     INFO     Agent fleet_safety_coordinator reasoning: idle               ]8;id=6023169;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023170;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent floor_associate tool call: read_notifications({})      ]8;id=6023175;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023176;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6023181;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6023182;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Agent robotics_engineer tool call: read_notifications({})    ]8;id=6023187;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023188;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6023193;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6023194;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     Agent fleet_safety_coordinator tool call:                    ]8;id=6023199;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023200;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#775\775]8;;\
#                              read_notifications({})
#                     INFO     Processing request of type CallToolRequest                               ]8;id=6023205;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=6023206;file:///Users/nsander/workspace/schmidt-poc/.venv/lib/python3.12/site-packages/mcp/server/lowlevel/server.py#733\733]8;;\
#                     INFO     All 4 rounds complete (after postmortem), ending simulation          ]8;id=6023212;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/game_clock.py\game_clock.py]8;;\:]8;id=6023213;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/game_clock.py#303\303]8;;\
#                     INFO     Game clock finished: scenario_complete                    ]8;id=6023219;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/autonomous_supervisor.py\autonomous_supervisor.py]8;;\:]8;id=6023220;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/autonomous_supervisor.py#534\534]8;;\
#                     INFO     Broadcasting done to 3 agents: scenario_complete               ]8;id=6023226;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/simulation_state.py\simulation_state.py]8;;\:]8;id=6023227;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/simulation_state.py#244\244]8;;\
#                     INFO     Agent floor_associate marked terminated: scenario_complete        ]8;id=6023234;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/agent_session.py\agent_session.py]8;;\:]8;id=6023235;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/agent_session.py#117\117]8;;\
#                     INFO     Agent robotics_engineer marked terminated: scenario_complete      ]8;id=6023240;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/agent_session.py\agent_session.py]8;;\:]8;id=6023241;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/agent_session.py#117\117]8;;\
#                     INFO     Agent fleet_safety_coordinator marked terminated:                 ]8;id=6023246;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/agent_session.py\agent_session.py]8;;\:]8;id=6023247;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runtime/agent_session.py#117\117]8;;\
#                              scenario_complete
#                     INFO     Agent floor_associate read_notifications returned done       ]8;id=6023253;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023254;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#832\832]8;;\
#                              signal
#                     INFO     Agent robotics_engineer read_notifications returned done     ]8;id=6023259;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023260;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#832\832]8;;\
#                              signal
#                     INFO     Agent fleet_safety_coordinator read_notifications returned   ]8;id=6023265;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023266;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#832\832]8;;\
#                              done signal
#                     INFO     Agent floor_associate reasoning:                             ]8;id=6023271;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023272;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent robotics_engineer reasoning:                           ]8;id=6023277;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023278;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent fleet_safety_coordinator reasoning:                    ]8;id=6023283;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023284;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent floor_associate cycle 24 complete: in=100 out=2        ]8;id=6023289;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023290;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              cache_read=0 cache_write=0 tokens
#                     INFO     Agent floor_associate reasoning: idle                        ]8;id=6023295;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023296;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent floor_associate received done notification after 24    ]8;id=6023302;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023303;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#502\502]8;;\
#                              turns, stopping
#                     INFO     Agent robotics_engineer cycle 24 complete: in=100 out=2      ]8;id=6023308;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023309;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              cache_read=0 cache_write=0 tokens
#                     INFO     Agent robotics_engineer reasoning: idle                      ]8;id=6023314;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023315;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent robotics_engineer received done notification after 24  ]8;id=6023320;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023321;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#502\502]8;;\
#                              turns, stopping
#                     INFO     Agent fleet_safety_coordinator cycle 23 complete: in=100     ]8;id=6023326;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023327;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#473\473]8;;\
#                              out=2 cache_read=0 cache_write=0 tokens
#                     INFO     Agent fleet_safety_coordinator reasoning: idle               ]8;id=6023332;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023333;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#629\629]8;;\
#                     INFO     Agent fleet_safety_coordinator received done notification    ]8;id=6023338;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023339;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#502\502]8;;\
#                              after 23 turns, stopping
#                     INFO     Agent floor_associate finished. Total turns: 24, total cost: ]8;id=6023345;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023346;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#531\531]8;;\
#                              $0.0000
#                     INFO     Agent robotics_engineer finished. Total turns: 24, total     ]8;id=6023351;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023352;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#531\531]8;;\
#                              cost: $0.0000
#                     INFO     Agent fleet_safety_coordinator finished. Total turns: 23,    ]8;id=6023357;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py\pydantic_ai_runner.py]8;;\:]8;id=6023358;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/runners/pydantic_ai_runner.py#531\531]8;;\
#                              total cost: $0.0000
#                     INFO     Stopping world simulation                                 ]8;id=6023364;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/autonomous_supervisor.py\autonomous_supervisor.py]8;;\:]8;id=6023365;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/autonomous_supervisor.py#560\560]8;;\
#                     INFO     Stopping MCP server                                       ]8;id=6023371;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/autonomous_supervisor.py\autonomous_supervisor.py]8;;\:]8;id=6023372;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/autonomous_supervisor.py#571\571]8;;\
#                     INFO     Simulation complete. Total messages: 9, total cost:       ]8;id=6023378;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/autonomous_supervisor.py\autonomous_supervisor.py]8;;\:]8;id=6023379;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/autonomous_supervisor.py#592\592]8;;\
#                              $0.0000
#                     INFO     Event log closed:                                                   ]8;id=6023386;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/event_logger.py\event_logger.py]8;;\:]8;id=6023387;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/event_logger.py#70\70]8;;\
#                              /var/folders/b_/5cy1dmx94wn81w9y4x6x8zc40000gn/T/tmpfhdd_klj/smoke.
#                              jsonl
# 364 events at /var/folders/b_/5cy1dmx94wn81w9y4x6x8zc40000gn/T/tmpfhdd_klj/smoke.jsonl

# %% [markdown]
# ## The deterministic metrics cost nothing
#
# These read the event log and compute. No judge, no provider, no spend, and the
# same answer every time.

# %%
from glossogen.evaluation.metric_core.metric_run_options import MetricRunOptions
from glossogen.testing import MetricRun, score_metrics

DETERMINISTIC = [
    "round_success",
    "mean_chars_per_round",
    "mean_chars_per_message",
    "round_ended_idle",
    "round_ended_timeout",
]

run_dir = result.log_path.parent
run = MetricRun(
    scenario=result.scenario,
    run_dir=run_dir,
    log_path=result.log_path,
    simulation=result,
)

with MonkeyPatch.context() as patch:
    scored = await score_metrics(
        run=run,
        metric_names=DETERMINISTIC,
        judge_responses=[],
        options=MetricRunOptions(probe_round=None, probe_replicas=1, ontology_path=None),
        report_path=run_dir / "report_deterministic.json",
        monkeypatch=patch,
    )

for measurement in scored.report.measurements:
    print(f"{measurement.metric_name:24} {measurement.score:>8.2f}  {measurement.score_unit}")
# Out:
#                     INFO     Loaded 364 events from                                                ]8;id=6023394;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/log_reader.py\log_reader.py]8;;\:]8;id=6023395;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/log_reader.py#54\54]8;;\
#                              /var/folders/b_/5cy1dmx94wn81w9y4x6x8zc40000gn/T/tmpfhdd_klj/smoke.js
#                              onl
#                     INFO     Running metric: round_success                         ]8;id=6023402;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py\scenario_evaluation_runner.py]8;;\:]8;id=6023403;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py#79\79]8;;\
#                     INFO     Metric round_success finished: round_success          ]8;id=6023409;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py\scenario_evaluation_runner.py]8;;\:]8;id=6023410;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py#94\94]8;;\
#                              score=0.000 (fraction of rounds succeeded (0/4))
#                     INFO     Running metric: mean_chars_per_round                  ]8;id=6023415;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py\scenario_evaluation_runner.py]8;;\:]8;id=6023416;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py#79\79]8;;\
#                     INFO     mcr metric: channel=radio 258.0 chars/round over 1 rounds (258 total  ]8;id=6023423;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/metrics/mcr_metric.py\mcr_metric.py]8;;\:]8;id=6023424;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/metrics/mcr_metric.py#94\94]8;;\
#                              chars)
#                     INFO     Metric mean_chars_per_round finished:                 ]8;id=6023429;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py\scenario_evaluation_runner.py]8;;\:]8;id=6023430;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py#94\94]8;;\
#                              mean_chars_per_round score=258.000 (chars/round)
#                     INFO     Running metric: mean_chars_per_message                ]8;id=6023435;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py\scenario_evaluation_runner.py]8;;\:]8;id=6023436;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py#79\79]8;;\
#                     INFO     mcm metric: channel=radio 28.67 chars/msg over 9 msgs in 1 rounds    ]8;id=6023443;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/metrics/mcm_metric.py\mcm_metric.py]8;;\:]8;id=6023444;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/metrics/mcm_metric.py#109\109]8;;\
#                     INFO     Metric mean_chars_per_message finished:               ]8;id=6023449;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py\scenario_evaluation_runner.py]8;;\:]8;id=6023450;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py#94\94]8;;\
#                              mean_chars_per_message score=28.667 (chars/message)
#                     INFO     Running metric: round_ended_idle                      ]8;id=6023455;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py\scenario_evaluation_runner.py]8;;\:]8;id=6023456;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py#79\79]8;;\
#                     INFO     round_ended_idle: total=4 identified=[2, 3, 4]           ]8;id=6023463;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/metrics/round_ended/round_ended_idle_metric.py\round_ended_idle_metric.py]8;;\:]8;id=6023464;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/metrics/round_ended/round_ended_idle_metric.py#71\71]8;;\
#                     INFO     Metric round_ended_idle finished: round_ended_idle    ]8;id=6023469;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py\scenario_evaluation_runner.py]8;;\:]8;id=6023470;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py#94\94]8;;\
#                              score=3.000 (rounds ended via all_agents_idle (out of
#                              4))
#                     INFO     Running metric: round_ended_timeout                   ]8;id=6023475;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py\scenario_evaluation_runner.py]8;;\:]8;id=6023476;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py#79\79]8;;\
#                     INFO     round_ended_timeout: total=4 identified=[]            ]8;id=6023483;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/metrics/round_ended/round_ended_timeout_metric.py\round_ended_timeout_metric.py]8;;\:]8;id=6023484;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/metrics/round_ended/round_ended_timeout_metric.py#71\71]8;;\
#                     INFO     Metric round_ended_timeout finished:                  ]8;id=6023489;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py\scenario_evaluation_runner.py]8;;\:]8;id=6023490;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py#94\94]8;;\
#                              round_ended_timeout score=0.000 (rounds ended via
#                              round_timeout (out of 4))
#                     INFO     Evaluation report written to                                   ]8;id=6023497;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/reports/evaluation_report.py\evaluation_report.py]8;;\:]8;id=6023498;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/reports/evaluation_report.py#52\52]8;;\
#                              /var/folders/b_/5cy1dmx94wn81w9y4x6x8zc40000gn/T/tmpfhdd_klj/r
#                              eport_deterministic.json
# round_success                0.00  fraction of rounds succeeded (0/4)
# mean_chars_per_round       258.00  chars/round
# mean_chars_per_message      28.67  chars/message
# round_ended_idle             3.00  rounds ended via all_agents_idle (out of 4)
# round_ended_timeout          0.00  rounds ended via round_timeout (out of 4)

# %% [markdown]
# `judge_responses=[]` is the assertion that none of these calls a model. Had one
# tried, the stub judge would have failed with the schema it asked for rather than
# inventing an answer, so a metric cannot quietly score against a fabricated
# judgement.
#
# Two of those numbers are worth reading together.

# %%
idle = scored.measurement(metric_name="round_ended_idle")
timeout = scored.measurement(metric_name="round_ended_timeout")
print(f"ended because the agents stopped talking: {idle.score:.2f}")
print(f"ended because the clock ran out:          {timeout.score:.2f}")
# Out:
# ended because the agents stopped talking: 3.00
# ended because the clock ran out:          0.00

# %% [markdown]
# If rounds end on the timeout, the throughput numbers are measuring the time limit
# rather than the agents, and `mean_chars_per_round` stops meaning what you think.
# Check this pair before believing a throughput result.
#
# ## Per-round detail
#
# A `Measurement` carries more than its headline score. `per_round` is what a plot
# reads, and `per_agent` is what a per-agent breakdown reads.

# %%
import pandas as pd

throughput = scored.measurement(metric_name="mean_chars_per_round")
frame = pd.DataFrame(
    [
        {"round": observation.round_number, "value": observation.value, "note": observation.note}
        for observation in throughput.per_round
    ]
)
frame
# Out:
#    round  value        note
# 0      1  258.0  9 messages

# %% [markdown]
# ## The judge-backed metrics, without spending
#
# The language findings come from LLM judges. In a real evaluation those cost money;
# here the judge is a stub whose answers this notebook chooses, which means you can
# see the whole path, including what the judge is shown, without a key.
#
# That is usually the interesting part. Not what the judge said, but what it was
# asked.

# %%
from glossogen.evaluation.metrics.shorthand_codes_metric import ShorthandCodesOutput

rounds = len(result.of_type(event_type="round_result_recorded"))
answers = [
    ShorthandCodesOutput(
        per_round_notes=[],
        systematic=False,
        messages_shortened=False,
        shared_understanding=False,
        explanation="Scripted agents send fixed text, so there is no code to find.",
    )
    for _ in range(rounds)
]

with MonkeyPatch.context() as patch:
    judged = await score_metrics(
        run=run,
        metric_names=["shorthand_codes"],
        judge_responses=answers,
        options=MetricRunOptions(probe_round=None, probe_replicas=1, ontology_path=None),
        report_path=run_dir / "report_judged.json",
        monkeypatch=patch,
    )

print(judged.measurement(metric_name="shorthand_codes").summary)
print(f"\njudge calls made: {len(judged.judge.calls)}")
# Out:
#                     INFO     Loaded 364 events from                                                ]8;id=6023503;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/log_reader.py\log_reader.py]8;;\:]8;id=6023504;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/log_reader.py#54\54]8;;\
#                              /var/folders/b_/5cy1dmx94wn81w9y4x6x8zc40000gn/T/tmpfhdd_klj/smoke.js
#                              onl
#                     INFO     Running metric: shorthand_codes                       ]8;id=6023509;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py\scenario_evaluation_runner.py]8;;\:]8;id=6023510;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py#79\79]8;;\
#                     INFO     Metric shorthand_codes finished: shorthand_codes      ]8;id=6023515;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py\scenario_evaluation_runner.py]8;;\:]8;id=6023516;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/scenario_evaluation_runner.py#94\94]8;;\
#                              score=0.000 (rounds with shorthand codes (out of 1))
#                     INFO     Evaluation report written to                                   ]8;id=6023521;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/reports/evaluation_report.py\evaluation_report.py]8;;\:]8;id=6023522;file:///Users/nsander/workspace/schmidt-poc/src/glossogen/evaluation/reports/evaluation_report.py#52\52]8;;\
#                              /var/folders/b_/5cy1dmx94wn81w9y4x6x8zc40000gn/T/tmpfhdd_klj/r
#                              eport_judged.json
# 0/1 rounds contained shorthand codes. Scripted agents send fixed text, so there is no code to find.
#
# judge calls made: 1

# %% [markdown]
# One call per round, and the metric asked each one about that round's messages
# alone. Inspect what a judge was actually shown:

# %%
call = judged.judge.calls[0]
print("schema asked for:", call.output_schema.__name__)
print()
print(call.messages[0].content[:700])
# Out:
# schema asked for: ShorthandCodesOutput
#
# You are evaluating whether agents in a multi-agent simulation developed shorthand codes, abbreviation systems, or symbolic notation during their communication across 1 rounds.
#
# Focus on the PRIMARY CHANNEL messages — these are the budget-constrained communications where codes and compression are most likely to emerge. Messages from OTHER CHANNELS provide context but are secondary.
#
# IMPORTANT: Other specialized evaluators cover different phenomena. Only report what belongs to THIS evaluator:
#
# - **Neologisms** (covered separately): invented words with new meanings, compound words, portmanteaus. If agents invent a NEW WORD (e.g., "chromaflux"), that is a neologism, NOT a code. Do NOT report it

# %% [markdown]
# Next: [03_compare_runs.ipynb](03_compare_runs.ipynb) puts two runs side by side,
# which is the shape of an actual experiment.
